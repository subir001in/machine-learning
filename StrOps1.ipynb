# %% [markdown]
# # How to write Strings and perform Simple Operations on String.

# %%
str1 = 'single quotes way'; str1
# Out:
# 'single quotes way'

# %%
str2 = "double quotes way"; str2
# Out:
# 'double quotes way'

# %% [markdown]
# ##Create Strings spanning multiple lines using ''' Triple Quotes

# %%
str3 = '''
Long string spanning
multiple lines
triple quotes way.
''' ; str3
# Out:
# '\nLong string spanning\nmultiple lines\ntriple quotes way.\n'

# %%
print(str3)
# Out:
# Long string spanning
# multiple lines
# triple quotes way.

# %% [markdown]
# ## Find the no of lines in a string.
#
# *   count('\n')

# %%
str3.count('\n')
# Out:
# 4

# %%
lines = str3.count('\n') - 1; lines
# Out:
# 3

# %% [markdown]
# ##Since Python strings are Immutable, to modify a string we need to use *replace()* method
#
# *   *replace()*

# %%
str4 = "It is a string string" ; str4
# Out:
# 'It is a string string'

# %%
str4.replace('string', 'long string');str4
# Out:
# 'It is a string string'

# %% [markdown]
# ## Concatenate 2 strings, using *+* *operator*.

# %%
str1 + ' or ' + str2
# Out:
# 'single quotes way or double quotes way'

# %% [markdown]
# ## Converting a String into a sequence of Unicode Characters.

# %%
list('123')
# Out:
# ['1', '2', '3']

# %%
list('It is a long string.')
# Out:
# ['I',
#  't',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'a',
#  ' ',
#  'l',
#  'o',
#  'n',
#  'g',
#  ' ',
#  's',
#  't',
#  'r',
#  'i',
#  'n',
#  'g',
#  '.']

# %% [markdown]
# #Slicing on teh Unicode Sequence created above.

# %%
str4 = list('It is a long string.') ; str4
# Out:
# ['I',
#  't',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'a',
#  ' ',
#  'l',
#  'o',
#  'n',
#  'g',
#  ' ',
#  's',
#  't',
#  'r',
#  'i',
#  'n',
#  'g',
#  '.']

# %%
str4[:7]
# Out:
# ['I', 't', ' ', 'i', 's', ' ', 'a']

# %%
'It is a long string'[:7]
# Out:
# 'It is a'

# %% [markdown]
# ##How to write *SPECIAL CHARACTERS*, perform *STRING FORMATTING* and *STRING PROCESSING* in Python.

# %%
'12\34'
# Out:
# '12\x1c'

# %%
print('12\34')
# Out:
# 12

# %%
r'12\34'
# Out:
# '12\\34'

# %%
print(r'12\34')
# Out:
# 12\34

# %%
'12\n34'
# Out:
# '12\n34'

# %%
print('12\n34')
# Out:
# 12
# 34

# %% [markdown]
# ##STRING FORMATING

# %%
strtmp = 'US-IND exchange rate: {0} Indian rupees are worth US${1}'
inr = 71.45; usd = 1
strtmp.format(inr,usd)
# Out:
# 'US-IND exchange rate: 71.45 Indian rupees are worth US$1'

# %% [markdown]
# ##STRING AND TEST PROCESSING

# %%
str = '1, 12, 123, 1234, 12345'; str
# Out:
# '1, 12, 123, 1234, 12345'

# %%
str.split(',')
# Out:
# ['1', ' 12', ' 123', ' 1234', ' 12345']

# %%
str1 = 'a, ab, abc, abcd, abcde' ; str1
# Out:
# 'a, ab, abc, abcd, abcde'

# %%
[x.strip() for x in str1.split(',')]
# Out:
# ['a', 'ab', 'abc', 'abcd', 'abcd e']

# %% [markdown]
# ##Concatenate strings with Delimiter.
#
# *   use *join()* method.

# %%
'::'.join([x.strip() for x in str1.split(',')])
# Out:
# 'a::ab::abc::abcd::abcde'

# %% [markdown]
# ##Check the presence of a term in a String
#
# *   use *in* keyword.

# %%
'abcd' in str1
# Out:
# True

# %% [markdown]
# ##Find index of a term inside a string
#
# *   use *index()* method.

# %%
str1.index('abcd')
# Out:
# 12

# %% [markdown]
# ## Count the occurances of a term inside a string.
#
# *   use *count()* method.

# %%
str1.count('abcd')
# Out:
# 2

# %% [markdown]
# ##To replace a term inside a string with a substitute
#
# *   use the *replace()* method.

# %%
str1.replace('abc','xyz')
# Out:
# 'a, ab, xyz, xyzd, xyzde'
