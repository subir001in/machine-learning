# %%
a=4

# %%
a
# Out:
# 4

# %%
a=5; b=6; c=7.5

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %%
c
# Out:
# 7.5

# %%
for x in range(1,10):
  if x<5:
    print(x, 'is less than 5')
  else:
    print(x,' is greater greater than or equal to 5') ## Comments
# Out:
# 1 is less than 5
# 2 is less than 5
# 3 is less than 5
# 4 is less than 5
# 5  is greater greater than or equal to 5
# 6  is greater greater than or equal to 5
# 7  is greater greater than or equal to 5
# 8  is greater greater than or equal to 5
# 9  is greater greater than or equal to 5

# %%
type(a)
# Out:
# int

# %%
type(c)
# Out:
# float

# %%
a.real
# Out:
# 5

# %%
a.bit_length()
# Out:
# 3

# %% [markdown]
# #FUNCTIONS IN PYTHON

# %%
def g():
  print('function with no arguments.')

# %%
g()
# Out:
# function with no arguments.

# %% [markdown]
# #Positional and Keyword Arguments of a function...
# ## Positional Arguments of a function, needs to be specified in a specific order while invoking
#
# ##Keyword Arguments of a function, need not be specified in a specific order while invoking

# %%
def f(x,y,z):
  a=4
  return(x+y)/z

# %%
f(a,b,c)
# Out:
# 1.4666666666666666

# %%
(5+6)/7.5
# Out:
# 1.4666666666666666

# %%
ret=f(a,b,c); ret
# Out:
# 1.4666666666666666

# %%
def h(x,y,z,w=9, t='bharat'):
  print(t,(x+y+z)/w)

# %%
h(a,b,c,t='india',w=5)
# Out:
# india 3.7

# %% [markdown]
# #Variables

# %%
weight=60 ; type(weight)
# Out:
# int

# %%
height=6.08 ;type(height)
# Out:
# float

# %%
gender='M'; type(gender)
# Out:
# str

# %%
infected=True ; type(infected)
# Out:
# bool

# %% [markdown]
# #TYPECASTING

# %%
int(infected)
# Out:
# 1

# %%
type(int(infected))
# Out:
# int

# %%
float(weight)
# Out:
# 60.0

# %%
type(float(weight))
# Out:
# float

# %%
str(infected)
# Out:
# 'True'

# %%
type(str(infected))
# Out:
# str

# %%
bool(gender)
# Out:
# True

# %% [markdown]
# #Object References in Python

# %%
x1=10.0;

# %%
x2=x1;

# %%
x1=20.0; print(x1); print(x2);
# Out:
# 20.0
# 10.0

# %%
print(type(x1))
# Out:
# <class 'float'>

# %%
x2='bharat'

# %%
print(type(x2))
# Out:
# <class 'str'>

# %% [markdown]
# #Implicit Casting
